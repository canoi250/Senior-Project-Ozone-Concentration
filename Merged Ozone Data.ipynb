# %%
import pandas as pd
import requests
import numpy as np

# %%
#define a variable Link1 that contains a URL to an API endpoint for extracting daily air quality data for Barnstable county in Massachusetts, USA, for ozone from January to December 2018.
Link1 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=001"

# %%
#Parses the response content as JSON using the json() method of the response object, and assigns the resulting JSON data to a variable json_data1.
r1=requests.get(url=Link1)
json_data1=r1.json()
json_data1
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2023-05-15T22:08:31-04:00',
#    'url': 'https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=001',
#    'rows': 1448}],
#  'Data': [{'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029792,
#    'first_max_value': 0.033,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0305,
#    'first_max_value': 0.032,
#    'first_max_hour': 13,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0305,
#    'first_max_value': 0.032,
#    'first_max_hour': 13,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.031412,
#    'first_max_value': 0.032,
#    'first_max_hour': 13,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033261,
#    'first_max_value': 0.035,
#    'first_max_hour': 13,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032375,
#    'first_max_value': 0.034,
#    'first_max_hour': 9,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032375,
#    'first_max_value': 0.034,
#    'first_max_hour': 9,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032412,
#    'first_max_value': 0.034,
#    'first_max_hour': 9,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030583,
#    'first_max_value': 0.034,
#    'first_max_hour': 11,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029667,
#    'first_max_value': 0.032,
#    'first_max_hour': 10,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029667,
#    'first_max_value': 0.032,
#    'first_max_hour': 10,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030118,
#    'first_max_value': 0.032,
#    'first_max_hour': 10,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029783,
#    'first_max_value': 0.035,
#    'first_max_hour': 20,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030583,
#    'first_max_value': 0.034,
#    'first_max_hour': 17,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030583,
#    'first_max_value': 0.034,
#    'first_max_hour': 17,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032,
#    'first_max_value': 0.034,
#    'first_max_hour': 17,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034083,
#    'first_max_value': 0.036,
#    'first_max_hour': 12,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033792,
#    'first_max_value': 0.035,
#    'first_max_hour': 6,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033792,
#    'first_max_value': 0.035,
#    'first_max_hour': 6,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033647,
#    'first_max_value': 0.035,
#    'first_max_hour': 7,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032391,
#    'first_max_value': 0.04,
#    'first_max_hour': 12,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029333,
#    'first_max_value': 0.036,
#    'first_max_hour': 5,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029333,
#    'first_max_value': 0.036,
#    'first_max_hour': 5,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.026882,
#    'first_max_value': 0.036,
#    'first_max_hour': 7,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 22,
#    'observation_percent': 92.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.022818,
#    'first_max_value': 0.037,
#    'first_max_hour': 23,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.02475,
#    'first_max_value': 0.036,
#    'first_max_hour': 22,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.02475,
#    'first_max_value': 0.036,
#    'first_max_hour': 22,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.027353,
#    'first_max_value': 0.036,
#    'first_max_hour': 22,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.035125,
#    'first_max_value': 0.039,
#    'first_max_hour': 1,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034667,
#    'first_max_value': 0.035,
#    'first_max_hour': 0,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034667,
#    'first_max_value': 0.035,
#    'first_max_hour': 0,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034765,
#    'first_max_value': 0.035,
#    'first_max_hour': 11,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036833,
#    'first_max_value': 0.039,
#    'first_max_hour': 10,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036417,
#    'first_max_value': 0.038,
#    'first_max_hour': 6,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036417,
#    'first_max_value': 0.038,
#    'first_max_hour': 6,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036294,
#    'first_max_value': 0.038,
#    'first_max_hour': 7,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.038792,
#    'first_max_value': 0.043,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037083,
#    'first_max_value': 0.042,
#    'first_max_hour': 12,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037083,
#    'first_max_value': 0.042,
#    'first_max_hour': 12,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037059,
#    'first_max_value': 0.042,
#    'first_max_hour': 12,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032708,
#    'first_max_value': 0.036,
#    'first_max_hour': 7,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033167,
#    'first_max_value': 0.035,
#    'first_max_hour': 7,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033167,
#    'first_max_value': 0.035,
#    'first_max_hour': 7,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034235,
#    'first_max_value': 0.035,
#    'first_max_hour': 7,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034042,
#    'first_max_value': 0.038,
#    'first_max_hour': 21,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032958,
#    'first_max_value': 0.035,
#    'first_max_hour': 14,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032958,
#    'first_max_value': 0.035,
#    'first_max_hour': 14,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033,
#    'first_max_value': 0.035,
#    'first_max_hour': 14,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-13',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034292,
#    'first_max_value': 0.038,
#    'first_max_hour': 14,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
# ...
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 22,
#    'observation_percent': 92.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034727,
#    'first_max_value': 0.04,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034375,
#    'first_max_value': 0.037,
#    'first_max_hour': 4,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034375,
#    'first_max_value': 0.037,
#    'first_max_hour': 4,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033706,
#    'first_max_value': 0.037,
#    'first_max_hour': 8,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036042,
#    'first_max_value': 0.04,
#    'first_max_hour': 7,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037167,
#    'first_max_value': 0.042,
#    'first_max_hour': 22,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037167,
#    'first_max_value': 0.042,
#    'first_max_hour': 22,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037059,
#    'first_max_value': 0.042,
#    'first_max_hour': 22,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.044542,
#    'first_max_value': 0.055,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.042208,
#    'first_max_value': 0.052,
#    'first_max_hour': 12,
#    'aqi': 48,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.042208,
#    'first_max_value': 0.052,
#    'first_max_hour': 12,
#    'aqi': 48,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.042588,
#    'first_max_value': 0.052,
#    'first_max_hour': 12,
#    'aqi': 48,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.031333,
#    'first_max_value': 0.041,
#    'first_max_hour': 18,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0305,
#    'first_max_value': 0.033,
#    'first_max_hour': 13,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0305,
#    'first_max_value': 0.033,
#    'first_max_hour': 13,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030706,
#    'first_max_value': 0.033,
#    'first_max_hour': 13,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   ...]}

# %%
#We write the contents of the CSV file "output.csv" into a pandas DataFrame named df1.
df1 = pd.json_normalize(json_data1["Data"])
df1.to_csv("output.csv", index=False)
df1
# Out:
#      state_code county_code site_number parameter_code  poc   latitude  \
# 0            25         001        0002          44201    1  41.975804
# 1            25         001        0002          44201    1  41.975804
# 2            25         001        0002          44201    1  41.975804
# 3            25         001        0002          44201    1  41.975804
# 4            25         001        0002          44201    1  41.975804
# ...         ...         ...         ...            ...  ...        ...
# 1443         25         001        0002          44201    1  41.975804
# 1444         25         001        0002          44201    1  41.975804
# 1445         25         001        0002          44201    1  41.975804
# 1446         25         001        0002          44201    1  41.975804
# 1447         25         001        0002          44201    1  41.975804
#
#       longitude  datum parameter sample_duration_code  ... method_code  \
# 0    -70.023598  WGS84     Ozone                    1  ...         087
# 1    -70.023598  WGS84     Ozone                    W  ...         087
# 2    -70.023598  WGS84     Ozone                    W  ...         087
# 3    -70.023598  WGS84     Ozone                    W  ...         087
# 4    -70.023598  WGS84     Ozone                    1  ...         087
# ...         ...    ...       ...                  ...  ...         ...
# 1443 -70.023598  WGS84     Ozone                    W  ...         087
# 1444 -70.023598  WGS84     Ozone                    1  ...         087
# 1445 -70.023598  WGS84     Ozone                    W  ...         087
# 1446 -70.023598  WGS84     Ozone                    W  ...         087
# 1447 -70.023598  WGS84     Ozone                    W  ...         087
#
#                                       method          local_site_name  \
# 0     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
# 1     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
# 2     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
# 3     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
# 4     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
# ...                                      ...                      ...
# 1443  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
# 1444  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
# 1445  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
# 1446  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
# 1447  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  TRURO NATIONAL SEASHORE
#
#          site_address          state      county   city cbsa_code  \
# 0     FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
# 1     FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
# 2     FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
# 3     FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
# 4     FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
# ...               ...            ...         ...    ...       ...
# 1443  FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
# 1444  FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
# 1445  FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
# 1446  FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
# 1447  FOX BOTTOM AREA  Massachusetts  Barnstable  Truro     12700
#
#                      cbsa  date_of_last_change
# 0     Barnstable Town, MA           2021-11-10
# 1     Barnstable Town, MA           2023-02-05
# 2     Barnstable Town, MA           2023-02-05
# 3     Barnstable Town, MA           2023-02-05
# 4     Barnstable Town, MA           2021-11-10
# ...                   ...                  ...
# 1443  Barnstable Town, MA           2023-02-05
# 1444  Barnstable Town, MA           2021-11-10
# 1445  Barnstable Town, MA           2023-02-05
# 1446  Barnstable Town, MA           2023-02-05
# 1447  Barnstable Town, MA           2023-02-05
#
# [1448 rows x 32 columns]

# %%
# Create a new dataframe with the two variables date_local and arithmentic mean. 
new_df1=df1.loc[:,["date_local", "arithmetic_mean"]]
new_df1
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.029792
# 1     2016-01-01         0.030500
# 2     2016-01-01         0.030500
# 3     2016-01-01         0.031412
# 4     2016-01-02         0.033261
# ...          ...              ...
# 1443  2016-12-30         0.033941
# 1444  2016-12-31         0.034542
# 1445  2016-12-31         0.033895
# 1446  2016-12-31         0.033895
# 1447  2016-12-31         0.035500
#
# [1448 rows x 2 columns]

# %% [markdown]
# Repeat the same process for ozone data in Norfolk county during 2016.

# %%
Q1 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=017"

# %%
r11=requests.get(url=Q1)
json_data11=r11.json()
json_data11
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2023-05-15T22:09:13-04:00',
#    'url': 'https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=017',
#    'rows': 1463}],
#  'Data': [{'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.028625,
#    'first_max_value': 0.033,
#    'first_max_hour': 12,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029375,
#    'first_max_value': 0.031,
#    'first_max_hour': 11,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029375,
#    'first_max_value': 0.031,
#    'first_max_hour': 11,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030412,
#    'first_max_value': 0.031,
#    'first_max_hour': 11,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.031087,
#    'first_max_value': 0.035,
#    'first_max_hour': 12,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029833,
#    'first_max_value': 0.033,
#    'first_max_hour': 9,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029833,
#    'first_max_value': 0.033,
#    'first_max_hour': 9,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029647,
#    'first_max_value': 0.033,
#    'first_max_hour': 9,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.026708,
#    'first_max_value': 0.033,
#    'first_max_hour': 14,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.024708,
#    'first_max_value': 0.031,
#    'first_max_hour': 11,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.024708,
#    'first_max_value': 0.031,
#    'first_max_hour': 11,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.025235,
#    'first_max_value': 0.031,
#    'first_max_hour': 11,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.024174,
#    'first_max_value': 0.029,
#    'first_max_hour': 14,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.025625,
#    'first_max_value': 0.028,
#    'first_max_hour': 9,
#    'aqi': 26,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.025625,
#    'first_max_value': 0.028,
#    'first_max_hour': 9,
#    'aqi': 26,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.027588,
#    'first_max_value': 0.028,
#    'first_max_hour': 9,
#    'aqi': 26,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.024458,
#    'first_max_value': 0.034,
#    'first_max_hour': 13,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.020958,
#    'first_max_value': 0.031,
#    'first_max_hour': 8,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.020958,
#    'first_max_value': 0.031,
#    'first_max_hour': 8,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.018235,
#    'first_max_value': 0.031,
#    'first_max_hour': 8,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 21,
#    'observation_percent': 88.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.018238,
#    'first_max_value': 0.036,
#    'first_max_hour': 13,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.016167,
#    'first_max_value': 0.031,
#    'first_max_hour': 9,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.016167,
#    'first_max_value': 0.031,
#    'first_max_hour': 9,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.017882,
#    'first_max_value': 0.031,
#    'first_max_hour': 9,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.005375,
#    'first_max_value': 0.02,
#    'first_max_hour': 13,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.004792,
#    'first_max_value': 0.014,
#    'first_max_hour': 9,
#    'aqi': 13,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.004792,
#    'first_max_value': 0.014,
#    'first_max_hour': 9,
#    'aqi': 13,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.005176,
#    'first_max_value': 0.014,
#    'first_max_hour': 9,
#    'aqi': 13,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.007174,
#    'first_max_value': 0.018,
#    'first_max_hour': 22,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.010625,
#    'first_max_value': 0.023,
#    'first_max_hour': 23,
#    'aqi': 21,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.010625,
#    'first_max_value': 0.023,
#    'first_max_hour': 23,
#    'aqi': 21,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.013765,
#    'first_max_value': 0.023,
#    'first_max_hour': 23,
#    'aqi': 21,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.018333,
#    'first_max_value': 0.025,
#    'first_max_hour': 12,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.015458,
#    'first_max_value': 0.022,
#    'first_max_hour': 0,
#    'aqi': 20,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.015458,
#    'first_max_value': 0.022,
#    'first_max_hour': 0,
#    'aqi': 20,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.013412,
#    'first_max_value': 0.02,
#    'first_max_hour': 7,
#    'aqi': 19,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.025217,
#    'first_max_value': 0.037,
#    'first_max_hour': 18,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.028375,
#    'first_max_value': 0.035,
#    'first_max_hour': 16,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.028375,
#    'first_max_value': 0.035,
#    'first_max_hour': 16,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032706,
#    'first_max_value': 0.035,
#    'first_max_hour': 16,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032917,
#    'first_max_value': 0.037,
#    'first_max_hour': 13,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.031083,
#    'first_max_value': 0.035,
#    'first_max_hour': 6,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.031083,
#    'first_max_value': 0.035,
#    'first_max_hour': 6,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030176,
#    'first_max_value': 0.035,
#    'first_max_hour': 7,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.014957,
#    'first_max_value': 0.03,
#    'first_max_hour': 0,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
# ...
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.016125,
#    'first_max_value': 0.03,
#    'first_max_hour': 10,
#    'aqi': 28,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.016765,
#    'first_max_value': 0.03,
#    'first_max_hour': 10,
#    'aqi': 28,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 22,
#    'observation_percent': 92.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.017591,
#    'first_max_value': 0.028,
#    'first_max_hour': 12,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.017583,
#    'first_max_value': 0.026,
#    'first_max_hour': 8,
#    'aqi': 24,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.017583,
#    'first_max_value': 0.026,
#    'first_max_hour': 8,
#    'aqi': 24,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.018412,
#    'first_max_value': 0.026,
#    'first_max_hour': 8,
#    'aqi': 24,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.021375,
#    'first_max_value': 0.031,
#    'first_max_hour': 20,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.023208,
#    'first_max_value': 0.029,
#    'first_max_hour': 15,
#    'aqi': 27,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.023208,
#    'first_max_value': 0.029,
#    'first_max_hour': 15,
#    'aqi': 27,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.026882,
#    'first_max_value': 0.029,
#    'first_max_hour': 15,
#    'aqi': 27,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.019125,
#    'first_max_value': 0.027,
#    'first_max_hour': 0,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0175,
#    'first_max_value': 0.022,
#    'first_max_hour': 0,
#    'aqi': 20,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0175,
#    'first_max_value': 0.022,
#    'first_max_hour': 0,
#    'aqi': 20,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.016647,
#    'first_max_value': 0.018,
#    'first_max_hour': 7,
#    'aqi': 17,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '017',
#    'site_number': '0009',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 42.62668,
#    'longitude': -71.362068,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.023,
#    'first_max_value': 0.031,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'USEPA REGION 1 LAB',
#    'site_address': '11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL LABORATORY',
#    'state': 'Massachusetts',
#    'county': 'Middlesex',
#    'city': 'Chelmsford (Chelmsford Center)',
#    'cbsa_code': '14460',
#    'cbsa': 'Boston-Cambridge-Newton, MA-NH',
#    'date_of_last_change': '2021-11-10'},
#   ...]}

# %%
df10 = pd.json_normalize(json_data11["Data"])
df10.to_csv("output.csv", index=False)
df10
# Out:
#      state_code county_code site_number parameter_code  poc  latitude  \
# 0            25         017        0009          44201    1  42.62668
# 1            25         017        0009          44201    1  42.62668
# 2            25         017        0009          44201    1  42.62668
# 3            25         017        0009          44201    1  42.62668
# 4            25         017        0009          44201    1  42.62668
# ...         ...         ...         ...            ...  ...       ...
# 1458         25         017        0009          44201    1  42.62668
# 1459         25         017        0009          44201    1  42.62668
# 1460         25         017        0009          44201    1  42.62668
# 1461         25         017        0009          44201    1  42.62668
# 1462         25         017        0009          44201    1  42.62668
#
#       longitude  datum parameter sample_duration_code  ... method_code  \
# 0    -71.362068  WGS84     Ozone                    1  ...         087
# 1    -71.362068  WGS84     Ozone                    W  ...         087
# 2    -71.362068  WGS84     Ozone                    W  ...         087
# 3    -71.362068  WGS84     Ozone                    W  ...         087
# 4    -71.362068  WGS84     Ozone                    1  ...         087
# ...         ...    ...       ...                  ...  ...         ...
# 1458 -71.362068  WGS84     Ozone                    W  ...         087
# 1459 -71.362068  WGS84     Ozone                    1  ...         087
# 1460 -71.362068  WGS84     Ozone                    W  ...         087
# 1461 -71.362068  WGS84     Ozone                    W  ...         087
# 1462 -71.362068  WGS84     Ozone                    W  ...         087
#
#                                       method     local_site_name  \
# 0     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
# 1     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
# 2     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
# 3     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
# 4     INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
# ...                                      ...                 ...
# 1458  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
# 1459  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
# 1460  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
# 1461  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
# 1462  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  USEPA REGION 1 LAB
#
#                                            site_address          state  \
# 0     11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
# 1     11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
# 2     11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
# 3     11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
# 4     11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
# ...                                                 ...            ...
# 1458  11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
# 1459  11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
# 1460  11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
# 1461  11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
# 1462  11 TECHNOLOGY DRIVE,  EPA NEW ENGLAND REGIONAL...  Massachusetts
#
#          county                            city cbsa_code  \
# 0     Middlesex  Chelmsford (Chelmsford Center)     14460
# 1     Middlesex  Chelmsford (Chelmsford Center)     14460
# 2     Middlesex  Chelmsford (Chelmsford Center)     14460
# 3     Middlesex  Chelmsford (Chelmsford Center)     14460
# 4     Middlesex  Chelmsford (Chelmsford Center)     14460
# ...         ...                             ...       ...
# 1458  Middlesex  Chelmsford (Chelmsford Center)     14460
# 1459  Middlesex  Chelmsford (Chelmsford Center)     14460
# 1460  Middlesex  Chelmsford (Chelmsford Center)     14460
# 1461  Middlesex  Chelmsford (Chelmsford Center)     14460
# 1462  Middlesex  Chelmsford (Chelmsford Center)     14460
#
#                                 cbsa  date_of_last_change
# 0     Boston-Cambridge-Newton, MA-NH           2021-11-10
# 1     Boston-Cambridge-Newton, MA-NH           2023-02-05
# 2     Boston-Cambridge-Newton, MA-NH           2023-02-05
# 3     Boston-Cambridge-Newton, MA-NH           2023-02-05
# 4     Boston-Cambridge-Newton, MA-NH           2021-11-10
# ...                              ...                  ...
# 1458  Boston-Cambridge-Newton, MA-NH           2023-02-05
# 1459  Boston-Cambridge-Newton, MA-NH           2021-11-10
# 1460  Boston-Cambridge-Newton, MA-NH           2023-02-05
# 1461  Boston-Cambridge-Newton, MA-NH           2023-02-05
# 1462  Boston-Cambridge-Newton, MA-NH           2023-02-05
#
# [1463 rows x 32 columns]

# %%
new_df10=df10.loc[:,["date_local", "arithmetic_mean"]]
new_df10
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.028625
# 1     2016-01-01         0.029375
# 2     2016-01-01         0.029375
# 3     2016-01-01         0.030412
# 4     2016-01-02         0.031087
# ...          ...              ...
# 1458  2016-12-30         0.032824
# 1459  2016-12-31         0.029083
# 1460  2016-12-31         0.027684
# 1461  2016-12-31         0.027684
# 1462  2016-12-31         0.029250
#
# [1463 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Bristol county.

# %%
Q16 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=005"

# %%
r16=requests.get(url=Q16)
json_data16=r16.json()

# %%
df16 = pd.json_normalize(json_data16["Data"])
df16.to_csv("output.csv", index=False)

# %%
new_df16=df16.loc[:,["date_local", "arithmetic_mean"]]
new_df16
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.026435
# 1     2016-01-01         0.026583
# 2     2016-01-01         0.026583
# 3     2016-01-01         0.026882
# 4     2016-01-02         0.028750
# ...          ...              ...
# 2921  2016-12-30         0.029824
# 2922  2016-12-31         0.030917
# 2923  2016-12-31         0.030579
# 2924  2016-12-31         0.030579
# 2925  2016-12-31         0.034917
#
# [2926 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Dukes county.

# %%
Q17 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=007"

# %%
r17=requests.get(url=Q17)
json_data17=r17.json()

# %%
df17 = pd.json_normalize(json_data17["Data"])
df17.to_csv("output.csv", index=False)

# %%
new_df17=df17.loc[:,["date_local", "arithmetic_mean"]]
new_df17
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.030250
# 1     2016-01-01         0.030417
# 2     2016-01-01         0.030417
# 3     2016-01-01         0.030824
# 4     2016-01-02         0.033826
# ...          ...              ...
# 1450  2016-12-30         0.031588
# 1451  2016-12-31         0.034542
# 1452  2016-12-31         0.034632
# 1453  2016-12-31         0.034632
# 1454  2016-12-31         0.037917
#
# [1455 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Essex county.

# %%
Q18 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=009"

# %%
r18=requests.get(url=Q18)
json_data18=r18.json()

# %%
df18 = pd.json_normalize(json_data18["Data"])
df18.to_csv("output.csv", index=False)

# %%
new_df18=df18.loc[:,["date_local", "arithmetic_mean"]]
new_df18
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.028957
# 1     2016-01-01         0.029667
# 2     2016-01-01         0.029667
# 3     2016-01-01         0.031353
# 4     2016-01-02         0.031083
# ...          ...              ...
# 4366  2016-12-30         0.034765
# 4367  2016-12-31         0.032375
# 4368  2016-12-31         0.031211
# 4369  2016-12-31         0.031211
# 4370  2016-12-31         0.031667
#
# [4371 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Franklin county.

# %%
Q19 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=011"

# %%
r19=requests.get(url=Q19)
json_data19=r19.json()

# %%
df19 = pd.json_normalize(json_data19["Data"])
df19.to_csv("output.csv", index=False)

# %%
new_df19=df19.loc[:,["date_local", "arithmetic_mean"]]
new_df19
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.031000
# 1     2016-01-01         0.030625
# 2     2016-01-01         0.030625
# 3     2016-01-01         0.030765
# 4     2016-01-02         0.031870
# ...          ...              ...
# 1451  2016-12-30         0.033235
# 1452  2016-12-31         0.028182
# 1453  2016-12-31         0.027000
# 1454  2016-12-31         0.027000
# 1455  2016-12-31         0.027833
#
# [1456 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Hampden county.

# %%
Q20 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=013"

# %%
r20=requests.get(url=Q20)
json_data20=r20.json()

# %%
df20 = pd.json_normalize(json_data20["Data"])
df20.to_csv("output.csv", index=False)

# %%
new_df20=df20.loc[:,["date_local", "arithmetic_mean"]]
new_df20
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.029167
# 1     2016-01-01         0.028917
# 2     2016-01-01         0.028917
# 3     2016-01-01         0.029706
# 4     2016-01-02         0.030087
# ...          ...              ...
# 1429  2016-12-30         0.030471
# 1430  2016-12-31         0.026917
# 1431  2016-12-31         0.026158
# 1432  2016-12-31         0.026158
# 1433  2016-12-31         0.028250
#
# [1434 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Hampshire county.

# %%
Q21 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=015"

# %%
r21=requests.get(url=Q21)
json_data21=r21.json()

# %%
df21 = pd.json_normalize(json_data1["Data"])
df21.to_csv("output.csv", index=False)

# %%
new_df21=df21.loc[:,["date_local", "arithmetic_mean"]]
new_df21
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.028625
# 1     2016-01-01         0.029375
# 2     2016-01-01         0.029375
# 3     2016-01-01         0.030412
# 4     2016-01-02         0.031087
# ...          ...              ...
# 1458  2016-12-30         0.032824
# 1459  2016-12-31         0.029083
# 1460  2016-12-31         0.027684
# 1461  2016-12-31         0.027684
# 1462  2016-12-31         0.029250
#
# [1463 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Norfolk county.

# %%
Q22 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=021"

# %%
r22=requests.get(url=Q22)
json_data22=r22.json()

# %%
df22 = pd.json_normalize(json_data22["Data"])
df22.to_csv("output.csv", index=False)

# %%
new_df22=df22.loc[:,["date_local", "arithmetic_mean"]]
new_df22
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.028522
# 1     2016-01-01         0.029292
# 2     2016-01-01         0.029292
# 3     2016-01-01         0.030294
# 4     2016-01-02         0.031875
# ...          ...              ...
# 1459  2016-12-30         0.032824
# 1460  2016-12-31         0.032250
# 1461  2016-12-31         0.031579
# 1462  2016-12-31         0.031579
# 1463  2016-12-31         0.034083
#
# [1464 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Plymouth county.

# %%
Q23 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=023"

# %%
r23=requests.get(url=Q23)
json_data23=r23.json()

# %%
df23 = pd.json_normalize(json_data23["Data"])
df23.to_csv("output.csv", index=False)

# %%
new_df23=df23.loc[:,["date_local", "arithmetic_mean"]]
new_df23
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.024217
# 1     2016-01-01         0.025000
# 2     2016-01-01         0.025000
# 3     2016-01-01         0.026000
# 4     2016-01-02         0.025708
# ...          ...              ...
# 1456  2016-12-30         0.029706
# 1457  2016-12-31         0.028208
# 1458  2016-12-31         0.027368
# 1459  2016-12-31         0.027368
# 1460  2016-12-31         0.031083
#
# [1461 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Suffolk county.

# %%
Q24 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=025"

# %%
r24=requests.get(url=Q24)
json_data24=r24.json()

# %%
df24 = pd.json_normalize(json_data24["Data"])
df24.to_csv("output.csv", index=False)

# %%
new_df24=df24.loc[:,["date_local", "arithmetic_mean"]]
new_df24
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.020739
# 1     2016-01-01         0.021875
# 2     2016-01-01         0.021875
# 3     2016-01-02         0.023000
# 4     2016-01-02         0.021625
# ...          ...              ...
# 1448  2016-12-30         0.025882
# 1449  2016-12-31         0.022833
# 1450  2016-12-31         0.021526
# 1451  2016-12-31         0.021526
# 1452  2016-12-31         0.023000
#
# [1453 rows x 2 columns]

# %% [markdown]
# Create a dataframe for the ozone concentration during 2016 in Worcester county.

# %%
Q25 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=027"

# %%
r25=requests.get(url=Q25)
json_data25=r25.json()

# %%
df25 = pd.json_normalize(json_data25["Data"])
df25.to_csv("output.csv", index=False)

# %%
new_df25=df25.loc[:,["date_local", "arithmetic_mean"]]
new_df25
# Out:
#       date_local  arithmetic_mean
# 0     2016-01-01         0.030783
# 1     2016-01-01         0.031000
# 2     2016-01-01         0.031000
# 3     2016-01-01         0.031824
# 4     2016-01-02         0.032583
# ...          ...              ...
# 2923  2016-12-30         0.031000
# 2924  2016-12-31         0.030542
# 2925  2016-12-31         0.030053
# 2926  2016-12-31         0.030053
# 2927  2016-12-31         0.033667
#
# [2928 rows x 2 columns]

# %%
from functools import reduce

dfs = [new_df1, new_df10, new_df16, new_df17, new_df18, new_df19, new_df20, new_df21, new_df22, new_df23, new_df24, new_df25]
merged_df = reduce(lambda left, right: pd.merge(left, right, on='arithmetic_mean', how='left'), dfs)
# Out:
# /var/folders/qr/3htbpbh94t1bt4cyn11s_ylc0000gn/T/ipykernel_49128/4153232089.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'date_local_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = reduce(lambda left, right: pd.merge(left, right, on='arithmetic_mean', how='left'), dfs)
# /var/folders/qr/3htbpbh94t1bt4cyn11s_ylc0000gn/T/ipykernel_49128/4153232089.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'date_local_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = reduce(lambda left, right: pd.merge(left, right, on='arithmetic_mean', how='left'), dfs)
# /var/folders/qr/3htbpbh94t1bt4cyn11s_ylc0000gn/T/ipykernel_49128/4153232089.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'date_local_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = reduce(lambda left, right: pd.merge(left, right, on='arithmetic_mean', how='left'), dfs)
# /var/folders/qr/3htbpbh94t1bt4cyn11s_ylc0000gn/T/ipykernel_49128/4153232089.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'date_local_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = reduce(lambda left, right: pd.merge(left, right, on='arithmetic_mean', how='left'), dfs)
# /var/folders/qr/3htbpbh94t1bt4cyn11s_ylc0000gn/T/ipykernel_49128/4153232089.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'date_local_x'} in the result is deprecated and will raise a MergeError in a future version.
#   merged_df = reduce(lambda left, right: pd.merge(left, right, on='arithmetic_mean', how='left'), dfs)

# %%
merged_df
# Out:
#          date_local_x  arithmetic_mean date_local_y date_local_x date_local_y  \
# 0          2016-01-01         0.029792          NaN   2016-03-04          NaN
# 1          2016-01-01         0.029792          NaN   2016-03-04          NaN
# 2          2016-01-01         0.029792          NaN   2016-03-04          NaN
# 3          2016-01-01         0.029792          NaN   2016-03-04          NaN
# 4          2016-01-01         0.029792          NaN   2016-03-04          NaN
# ...               ...              ...          ...          ...          ...
# 25083932   2016-12-31         0.035500   2016-12-15          NaN   2016-06-14
# 25083933   2016-12-31         0.035500   2016-12-15          NaN   2016-06-14
# 25083934   2016-12-31         0.035500   2016-12-15          NaN   2016-06-14
# 25083935   2016-12-31         0.035500   2016-12-15          NaN   2016-06-14
# 25083936   2016-12-31         0.035500   2016-12-15          NaN   2016-06-14
#
#          date_local_x date_local_y date_local_x date_local_y date_local_x  \
# 0          2016-09-08   2016-04-13   2016-05-29          NaN   2016-06-15
# 1          2016-09-08   2016-04-13   2016-05-29          NaN   2016-06-15
# 2          2016-09-08   2016-04-13   2016-05-29          NaN   2016-06-15
# 3          2016-09-08   2016-04-13   2016-05-29          NaN   2016-06-15
# 4          2016-09-08   2016-04-13   2016-05-29          NaN   2016-06-15
# ...               ...          ...          ...          ...          ...
# 25083932   2016-08-12   2016-01-18   2016-08-13   2016-12-15   2016-12-15
# 25083933   2016-08-12   2016-01-18   2016-08-13   2016-12-15   2016-12-15
# 25083934   2016-08-12   2016-01-18   2016-08-13   2016-12-15   2016-05-04
# 25083935   2016-08-12   2016-01-18   2016-08-13   2016-12-15   2016-12-15
# 25083936   2016-08-12   2016-01-18   2016-08-13   2016-12-15   2016-12-15
#
#          date_local_y date_local_x date_local_y
# 0                 NaN   2016-04-27   2016-03-11
# 1                 NaN   2016-04-27   2016-03-11
# 2                 NaN   2016-04-27   2016-07-16
# 3                 NaN   2016-04-27   2016-07-16
# 4                 NaN   2016-04-27   2016-03-11
# ...               ...          ...          ...
# 25083932          NaN          NaN   2016-04-06
# 25083933          NaN          NaN   2016-04-06
# 25083934          NaN          NaN   2016-04-06
# 25083935          NaN          NaN   2016-04-06
# 25083936          NaN          NaN   2016-04-06
#
# [25083937 rows x 13 columns]
