# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np 
from statsmodels.tsa.arima.model import ARIMA

# %%
#define a variable Link1 that contains a URL to an API endpoint for extracting daily air quality data for Barnstable county in Massachusetts, USA, for ozone from January to December 2018.
Link1 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=001"

# %%
#Parses the response content as JSON using the json() method of the response object, and assigns the resulting JSON data to a variable json_data1.
r1=requests.get(url=Link1)
json_data1=r1.json()
json_data1
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2023-05-15T22:45:01-04:00',
#    'url': 'https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20160101&edate=20161231&state=25&county=001',
#    'rows': 1448}],
#  'Data': [{'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029792,
#    'first_max_value': 0.033,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0305,
#    'first_max_value': 0.032,
#    'first_max_hour': 13,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0305,
#    'first_max_value': 0.032,
#    'first_max_hour': 13,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.031412,
#    'first_max_value': 0.032,
#    'first_max_hour': 13,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033261,
#    'first_max_value': 0.035,
#    'first_max_hour': 13,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032375,
#    'first_max_value': 0.034,
#    'first_max_hour': 9,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032375,
#    'first_max_value': 0.034,
#    'first_max_hour': 9,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032412,
#    'first_max_value': 0.034,
#    'first_max_hour': 9,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030583,
#    'first_max_value': 0.034,
#    'first_max_hour': 11,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029667,
#    'first_max_value': 0.032,
#    'first_max_hour': 10,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029667,
#    'first_max_value': 0.032,
#    'first_max_hour': 10,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030118,
#    'first_max_value': 0.032,
#    'first_max_hour': 10,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029783,
#    'first_max_value': 0.035,
#    'first_max_hour': 20,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030583,
#    'first_max_value': 0.034,
#    'first_max_hour': 17,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030583,
#    'first_max_value': 0.034,
#    'first_max_hour': 17,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032,
#    'first_max_value': 0.034,
#    'first_max_hour': 17,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034083,
#    'first_max_value': 0.036,
#    'first_max_hour': 12,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033792,
#    'first_max_value': 0.035,
#    'first_max_hour': 6,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033792,
#    'first_max_value': 0.035,
#    'first_max_hour': 6,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033647,
#    'first_max_value': 0.035,
#    'first_max_hour': 7,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032391,
#    'first_max_value': 0.04,
#    'first_max_hour': 12,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029333,
#    'first_max_value': 0.036,
#    'first_max_hour': 5,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029333,
#    'first_max_value': 0.036,
#    'first_max_hour': 5,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.026882,
#    'first_max_value': 0.036,
#    'first_max_hour': 7,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 22,
#    'observation_percent': 92.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.022818,
#    'first_max_value': 0.037,
#    'first_max_hour': 23,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.02475,
#    'first_max_value': 0.036,
#    'first_max_hour': 22,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.02475,
#    'first_max_value': 0.036,
#    'first_max_hour': 22,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.027353,
#    'first_max_value': 0.036,
#    'first_max_hour': 22,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.035125,
#    'first_max_value': 0.039,
#    'first_max_hour': 1,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034667,
#    'first_max_value': 0.035,
#    'first_max_hour': 0,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034667,
#    'first_max_value': 0.035,
#    'first_max_hour': 0,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034765,
#    'first_max_value': 0.035,
#    'first_max_hour': 11,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036833,
#    'first_max_value': 0.039,
#    'first_max_hour': 10,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036417,
#    'first_max_value': 0.038,
#    'first_max_hour': 6,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036417,
#    'first_max_value': 0.038,
#    'first_max_hour': 6,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036294,
#    'first_max_value': 0.038,
#    'first_max_hour': 7,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.038792,
#    'first_max_value': 0.043,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037083,
#    'first_max_value': 0.042,
#    'first_max_hour': 12,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037083,
#    'first_max_value': 0.042,
#    'first_max_hour': 12,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037059,
#    'first_max_value': 0.042,
#    'first_max_hour': 12,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032708,
#    'first_max_value': 0.036,
#    'first_max_hour': 7,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033167,
#    'first_max_value': 0.035,
#    'first_max_hour': 7,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033167,
#    'first_max_value': 0.035,
#    'first_max_hour': 7,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034235,
#    'first_max_value': 0.035,
#    'first_max_hour': 7,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034042,
#    'first_max_value': 0.038,
#    'first_max_hour': 21,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032958,
#    'first_max_value': 0.035,
#    'first_max_hour': 14,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032958,
#    'first_max_value': 0.035,
#    'first_max_hour': 14,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033,
#    'first_max_value': 0.035,
#    'first_max_hour': 14,
#    'aqi': 32,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-01-13',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034292,
#    'first_max_value': 0.038,
#    'first_max_hour': 14,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
# ...
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 22,
#    'observation_percent': 92.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034727,
#    'first_max_value': 0.04,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034375,
#    'first_max_value': 0.037,
#    'first_max_hour': 4,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034375,
#    'first_max_value': 0.037,
#    'first_max_hour': 4,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033706,
#    'first_max_value': 0.037,
#    'first_max_hour': 8,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036042,
#    'first_max_value': 0.04,
#    'first_max_hour': 7,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037167,
#    'first_max_value': 0.042,
#    'first_max_hour': 22,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037167,
#    'first_max_value': 0.042,
#    'first_max_hour': 22,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037059,
#    'first_max_value': 0.042,
#    'first_max_hour': 22,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.044542,
#    'first_max_value': 0.055,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.042208,
#    'first_max_value': 0.052,
#    'first_max_hour': 12,
#    'aqi': 48,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.042208,
#    'first_max_value': 0.052,
#    'first_max_hour': 12,
#    'aqi': 48,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.042588,
#    'first_max_value': 0.052,
#    'first_max_hour': 12,
#    'aqi': 48,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2016-09-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.031333,
#    'first_max_value': 0.041,
#    'first_max_hour': 18,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-10'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2016-09-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0305,
#    'first_max_value': 0.033,
#    'first_max_hour': 13,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2016-09-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0305,
#    'first_max_value': 0.033,
#    'first_max_hour': 13,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2016-09-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030706,
#    'first_max_value': 0.033,
#    'first_max_hour': 13,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   ...]}

# %%
#We write the contents of the CSV file "output.csv" into a pandas DataFrame named df1.
df1 = pd.json_normalize(json_data1["Data"])
df1.to_csv("output.csv", index=False)

# %%
# Create a new dataframe with the two variables date_local and arithmentic mean. 
new_df1=df1.loc[:,["date_local", "arithmetic_mean"]]

# %% [markdown]
# Repeat the same process for ozone data in Barnstable county during 2017

# %%
Link2 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20170101&edate=20171231&state=25&county=001"

# %%
r2=requests.get(url=Link2)

# %%
json_data2=r2.json()

# %%
df2 = pd.json_normalize(json_data2["Data"])

# %%
new_df2=df1.loc[:,["date_local", "arithmetic_mean"]]

# %% [markdown]
# Repeat the same process for ozone data in Barnstable county during 2018

# %%
Link3 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20180101&edate=20181231&state=25&county=001"

# %%
r3=requests.get(url=Link3)

# %%
json_data3= r3.json()
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2023-05-15T22:40:49-04:00',
#    'url': 'https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20180101&edate=20181231&state=25&county=001',
#    'rows': 1451}],
#  'Data': [{'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037833,
#    'first_max_value': 0.041,
#    'first_max_hour': 16,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037625,
#    'first_max_value': 0.04,
#    'first_max_hour': 12,
#    'aqi': 37,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037625,
#    'first_max_value': 0.04,
#    'first_max_hour': 12,
#    'aqi': 37,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-01',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.038471,
#    'first_max_value': 0.04,
#    'first_max_hour': 12,
#    'aqi': 37,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.035565,
#    'first_max_value': 0.038,
#    'first_max_hour': 15,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034458,
#    'first_max_value': 0.036,
#    'first_max_hour': 1,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034458,
#    'first_max_value': 0.036,
#    'first_max_hour': 1,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-02',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034118,
#    'first_max_value': 0.036,
#    'first_max_hour': 8,
#    'aqi': 33,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032,
#    'first_max_value': 0.036,
#    'first_max_hour': 11,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032583,
#    'first_max_value': 0.039,
#    'first_max_hour': 23,
#    'aqi': 36,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032583,
#    'first_max_value': 0.039,
#    'first_max_hour': 23,
#    'aqi': 36,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-03',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.032824,
#    'first_max_value': 0.039,
#    'first_max_hour': 23,
#    'aqi': 36,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.039667,
#    'first_max_value': 0.043,
#    'first_max_hour': 7,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0385,
#    'first_max_value': 0.042,
#    'first_max_hour': 2,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0385,
#    'first_max_value': 0.042,
#    'first_max_hour': 2,
#    'aqi': 39,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-04',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037235,
#    'first_max_value': 0.041,
#    'first_max_hour': 7,
#    'aqi': 38,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034174,
#    'first_max_value': 0.038,
#    'first_max_hour': 17,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033958,
#    'first_max_value': 0.037,
#    'first_max_hour': 15,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033958,
#    'first_max_value': 0.037,
#    'first_max_hour': 15,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-05',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.035176,
#    'first_max_value': 0.037,
#    'first_max_hour': 15,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037125,
#    'first_max_value': 0.038,
#    'first_max_hour': 5,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0365,
#    'first_max_value': 0.038,
#    'first_max_hour': 10,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0365,
#    'first_max_value': 0.038,
#    'first_max_hour': 10,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036529,
#    'first_max_value': 0.038,
#    'first_max_hour': 10,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036792,
#    'first_max_value': 0.039,
#    'first_max_hour': 13,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036625,
#    'first_max_value': 0.037,
#    'first_max_hour': 4,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036625,
#    'first_max_value': 0.037,
#    'first_max_hour': 4,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036765,
#    'first_max_value': 0.037,
#    'first_max_hour': 7,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.037565,
#    'first_max_value': 0.045,
#    'first_max_hour': 17,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034917,
#    'first_max_value': 0.041,
#    'first_max_hour': 12,
#    'aqi': 38,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034917,
#    'first_max_value': 0.041,
#    'first_max_hour': 12,
#    'aqi': 38,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034471,
#    'first_max_value': 0.041,
#    'first_max_hour': 12,
#    'aqi': 38,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.026792,
#    'first_max_value': 0.035,
#    'first_max_hour': 14,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.027125,
#    'first_max_value': 0.033,
#    'first_max_hour': 11,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.027125,
#    'first_max_value': 0.033,
#    'first_max_hour': 11,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030471,
#    'first_max_value': 0.033,
#    'first_max_hour': 11,
#    'aqi': 31,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029833,
#    'first_max_value': 0.033,
#    'first_max_hour': 11,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.03,
#    'first_max_value': 0.032,
#    'first_max_hour': 9,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.03,
#    'first_max_value': 0.032,
#    'first_max_hour': 9,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.030765,
#    'first_max_value': 0.032,
#    'first_max_hour': 9,
#    'aqi': 30,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.035435,
#    'first_max_value': 0.038,
#    'first_max_hour': 11,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.035917,
#    'first_max_value': 0.038,
#    'first_max_hour': 21,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.035917,
#    'first_max_value': 0.038,
#    'first_max_hour': 21,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-11',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036706,
#    'first_max_value': 0.038,
#    'first_max_hour': 21,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.036542,
#    'first_max_value': 0.039,
#    'first_max_hour': 0,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034667,
#    'first_max_value': 0.038,
#    'first_max_hour': 0,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.034667,
#    'first_max_value': 0.038,
#    'first_max_hour': 0,
#    'aqi': 35,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-01-12',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033588,
#    'first_max_value': 0.037,
#    'first_max_hour': 7,
#    'aqi': 34,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-01-13',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.033167,
#    'first_max_value': 0.04,
#    'first_max_hour': 10,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
# ...
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-09-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.03675,
#    'first_max_value': 0.049,
#    'first_max_hour': 10,
#    'aqi': 45,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-09-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.03675,
#    'first_max_value': 0.049,
#    'first_max_hour': 10,
#    'aqi': 45,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-09-06',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.038353,
#    'first_max_value': 0.049,
#    'first_max_hour': 10,
#    'aqi': 45,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.022917,
#    'first_max_value': 0.029,
#    'first_max_hour': 0,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.020792,
#    'first_max_value': 0.026,
#    'first_max_hour': 0,
#    'aqi': 24,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.020792,
#    'first_max_value': 0.026,
#    'first_max_hour': 0,
#    'aqi': 24,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-09-07',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.018706,
#    'first_max_value': 0.025,
#    'first_max_hour': 7,
#    'aqi': 23,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 23,
#    'observation_percent': 96.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.026174,
#    'first_max_value': 0.034,
#    'first_max_hour': 10,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.027458,
#    'first_max_value': 0.031,
#    'first_max_hour': 8,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.027458,
#    'first_max_value': 0.031,
#    'first_max_hour': 8,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-09-08',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.029824,
#    'first_max_value': 0.031,
#    'first_max_hour': 8,
#    'aqi': 29,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.024083,
#    'first_max_value': 0.03,
#    'first_max_hour': 0,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 1997',
#    'date_local': '2018-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.023167,
#    'first_max_value': 0.028,
#    'first_max_hour': 0,
#    'aqi': 26,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-Hour 2008',
#    'date_local': '2018-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.023167,
#    'first_max_value': 0.028,
#    'first_max_hour': 0,
#    'aqi': 26,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': 'W',
#    'sample_duration': '8-HR RUN AVG BEGIN HOUR',
#    'pollutant_standard': 'Ozone 8-hour 2015',
#    'date_local': '2018-09-09',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 17,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.022176,
#    'first_max_value': 0.025,
#    'first_max_hour': 23,
#    'aqi': 23,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2023-02-05'},
#   {'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '44201',
#    'poc': 1,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'parameter': 'Ozone',
#    'sample_duration_code': '1',
#    'sample_duration': '1 HOUR',
#    'pollutant_standard': 'Ozone 1-hour 1979',
#    'date_local': '2018-09-10',
#    'units_of_measure': 'Parts per million',
#    'event_type': 'No Events',
#    'observation_count': 24,
#    'observation_percent': 100.0,
#    'validity_indicator': 'Y',
#    'arithmetic_mean': 0.0285,
#    'first_max_value': 0.034,
#    'first_max_hour': 20,
#    'aqi': None,
#    'method_code': '087',
#    'method': 'INSTRUMENTAL - ULTRA VIOLET ABSORPTION',
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'site_address': 'FOX BOTTOM AREA',
#    'state': 'Massachusetts',
#    'county': 'Barnstable',
#    'city': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa': 'Barnstable Town, MA',
#    'date_of_last_change': '2021-11-04'},
#   ...]}

# %%
df3 = pd.json_normalize(json_data3["Data"])

# %%
new_df3=df1.loc[:,["date_local", "arithmetic_mean"]]

# %% [markdown]
# Repeat the same process for ozone data in Barnstable county during 2019

# %%
Link4 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20190101&edate=20191231&state=25&county=001"

# %%
r4=requests.get(url=Link4)

# %%
json_data4=r4.json()

# %%
df4 = pd.json_normalize(json_data4["Data"])
df4.to_csv("output.csv", index=False)

# %%
new_df4=df1.loc[:,["date_local", "arithmetic_mean"]]

# %% [markdown]
# Repeat the same process for ozone data in Barnstable county during 2020

# %%
Link5 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20200101&edate=20201231&state=25&county=001"

# %%
r5=requests.get(url=Link5)

# %%
r5.json()
json_data5 =r5.json()

# %%
df5 = pd.json_normalize(json_data5["Data"])
df5.to_csv("output.csv", index=False)

# %%
new_df5=df5.loc[:,["date_local", "arithmetic_mean"]]

# %% [markdown]
# Repeat the same process for ozone data in Barnstable county during 2021

# %%
Link6 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20210101&edate=20211231&state=25&county=001"

# %%
r6=requests.get(url=Link6)

# %%
json_data6=r6.json()

# %%
df6 = pd.json_normalize(json_data6["Data"])
df6.to_csv("output.csv", index=False)

# %%
new_df6=df6.loc[:,["date_local", "arithmetic_mean"]]

# %%
Link7 = "https://aqs.epa.gov/data/api/dailyData/byCounty?email=canoi@whitman.edu&key=goldmallard38&param=44201&bdate=20220101&edate=20220831&state=25&county=001"

# %% [markdown]
# Repeat the same process for ozone data in Barnstable county during 2022

# %%
r7=requests.get(url=Link7)

# %%
json_data7=r7.json()

# %%
df7 = pd.json_normalize(json_data7["Data"])
df7.to_csv("output.csv", index=False)

# %%
new_df7=df7.loc[:,["date_local", "arithmetic_mean"]]

# %% [markdown]
# Concatenate the data frames in order to create an ozone dataset for Barnstable county from 2016 up to 2022.

# %%
result = pd.concat([new_df1, new_df2, new_df3, new_df4, new_df5, new_df6, new_df7])

# %% [markdown]
# Create a scatter plot with time series data using the result dataframe.

# %%
x = result['date_local']
y = result['arithmetic_mean']

# %%
fig=plt.figure()
plt.close(fig)
plt.figure(figsize = (20,5))
plt.xlabel('Date')
plt.ylabel('Ozone concentration (ppm)', fontsize=16)
plt.title('Ozone Concentration In Barnstable County, MA from 2106-2022', fontsize=16)
plt.scatter(x, y)

# %%
#Create a new dataframe with the mean ozone value for every date. 
new_result=result.loc[:,["date_local", "arithmetic_mean"]]

# %%
result_mean = new_result.groupby("date_local")["arithmetic_mean"].mean()
result_mean.to_csv('result_mean.csv')
df = pd.read_csv('result_mean.csv').reset_index()

# %%
new_df=df.loc[:,["index", "arithmetic_mean"]]

# %% [markdown]
# Run ARIMA model for the new_df dataframe and forecast data using the ARIMA model (1,0,0)

# %%
model3 = ARIMA(new_df["arithmetic_mean"], order=(1, 0, 0))
model_fit3 = model3.fit()

print(model_fit3.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:        arithmetic_mean   No. Observations:                 1319
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                4814.404
# Date:                Mon, 15 May 2023   AIC                          -9622.808
# Time:                        19:46:06   BIC                          -9607.254
# Sample:                             0   HQIC                         -9616.976
#                                - 1319
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0349      0.000     81.030      0.000       0.034       0.036
# ar.L1          0.5947      0.020     30.318      0.000       0.556       0.633
# sigma2      3.953e-05   1.24e-06     31.871      0.000    3.71e-05     4.2e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.04   Jarque-Bera (JB):                94.35
# Prob(Q):                              0.31   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.20   Skew:                             0.19
# Prob(H) (two-sided):                  0.06   Kurtosis:                         4.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
